# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\91700\dataset_1.csv")

# %%
df
# Out:
#              destination  passanger weather  temperature  time  \
# 0        No Urgent Place      Alone   Sunny           55   2PM
# 1        No Urgent Place  Friend(s)   Sunny           80  10AM
# 2        No Urgent Place  Friend(s)   Sunny           80  10AM
# 3        No Urgent Place  Friend(s)   Sunny           80   2PM
# 4        No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                  ...        ...     ...          ...   ...
# 1048570  No Urgent Place  Friend(s)   Snowy           30  10AM
# 1048571  No Urgent Place  Friend(s)   Snowy           30  10PM
# 1048572  No Urgent Place      Alone   Sunny           80  10AM
# 1048573             Home      Alone   Sunny           30   6PM
# 1048574             Home      Alone   Rainy           55  10PM
#
#                         coupon expiration  gender     age      maritalStatus  \
# 0              Restaurant(<20)         1d  Female      21  Unmarried partner
# 1                 Coffee House         2h  Female      21  Unmarried partner
# 2        Carry out & Take away         2h  Female      21  Unmarried partner
# 3                 Coffee House         2h  Female      21  Unmarried partner
# 4                 Coffee House         1d  Female      21  Unmarried partner
# ...                        ...        ...     ...     ...                ...
# 1048570  Carry out & Take away         1d  Female  50plus             Single
# 1048571  Carry out & Take away         1d  Female  50plus             Single
# 1048572           Coffee House         1d  Female  50plus             Single
# 1048573  Carry out & Take away         2h  Female  50plus             Single
# 1048574           Coffee House         1d  Female  50plus             Single
#
#          ...  Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min  \
# 0        ...               1~3                1                 0
# 1        ...               1~3                1                 0
# 2        ...               1~3                1                 1
# 3        ...               1~3                1                 1
# 4        ...               1~3                1                 1
# ...      ...               ...              ...               ...
# 1048570  ...               1~3                1                 1
# 1048571  ...               1~3                1                 1
# 1048572  ...               1~3                1                 0
# 1048573  ...               1~3                1                 1
# 1048574  ...               1~3                1                 0
#
#         toCoupon_GEQ25min direction_same direction_opp  Y row_count df1 df2
# 0                       0              0             1  1         1 NaN NaN
# 1                       0              0             1  0         2 NaN NaN
# 2                       0              0             1  1         3 NaN NaN
# 3                       0              0             1  0         4 NaN NaN
# 4                       0              0             1  0         5 NaN NaN
# ...                   ...            ...           ... ..       ...  ..  ..
# 1048570                 0              0             1  0      8483 NaN NaN
# 1048571                 0              0             1  0      8484 NaN NaN
# 1048572                 0              0             1  1      8485 NaN NaN
# 1048573                 0              1             0  1      8486 NaN NaN
# 1048574                 0              1             0  0      8487 NaN NaN
#
# [1048575 rows x 29 columns]

# %%
df[['weather','temperature']]
# Out:
#         weather  temperature
# 0         Sunny           55
# 1         Sunny           80
# 2         Sunny           80
# 3         Sunny           80
# 4         Sunny           80
# ...         ...          ...
# 1048570   Snowy           30
# 1048571   Snowy           30
# 1048572   Sunny           80
# 1048573   Sunny           30
# 1048574   Rainy           55
#
# [1048575 rows x 2 columns]

# %%
df.head(10)
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
# 5  No Urgent Place  Friend(s)   Sunny           80   6PM
# 6  No Urgent Place  Friend(s)   Sunny           55   2PM
# 7  No Urgent Place     Kid(s)   Sunny           80  10AM
# 8  No Urgent Place     Kid(s)   Sunny           80  10AM
# 9  No Urgent Place     Kid(s)   Sunny           80  10AM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
# 5        Restaurant(<20)         2h  Female  21  Unmarried partner  ...
# 6  Carry out & Take away         1d  Female  21  Unmarried partner  ...
# 7        Restaurant(<20)         2h  Female  21  Unmarried partner  ...
# 8  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 9                    Bar         1d  Female  21  Unmarried partner  ...
#
#    Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min  \
# 0               1~3                1                 0                 0
# 1               1~3                1                 0                 0
# 2               1~3                1                 1                 0
# 3               1~3                1                 1                 0
# 4               1~3                1                 1                 0
# 5               1~3                1                 1                 0
# 6               1~3                1                 1                 0
# 7               1~3                1                 1                 0
# 8               1~3                1                 1                 0
# 9               1~3                1                 1                 0
#
#   direction_same direction_opp  Y row_count df1 df2
# 0              0             1  1         1 NaN NaN
# 1              0             1  0         2 NaN NaN
# 2              0             1  1         3 NaN NaN
# 3              0             1  0         4 NaN NaN
# 4              0             1  0         5 NaN NaN
# 5              0             1  1         6 NaN NaN
# 6              0             1  1         7 NaN NaN
# 7              0             1  1         8 NaN NaN
# 8              0             1  1         9 NaN NaN
# 9              0             1  0        10 NaN NaN
#
# [10 rows x 29 columns]

# %%
df['passanger'].unique()
# Out:
# array(['Alone', 'Friend(s)', 'Kid(s)', 'Partner'], dtype=object)

# %%
df[df['destination']=='Home']
# Out:
#         destination passanger weather  temperature  time  \
# 13             Home     Alone   Sunny           55   6PM
# 14             Home     Alone   Sunny           55   6PM
# 15             Home     Alone   Sunny           80   6PM
# 35             Home     Alone   Sunny           55   6PM
# 36             Home     Alone   Sunny           55   6PM
# ...             ...       ...     ...          ...   ...
# 1048554        Home     Alone   Snowy           30  10PM
# 1048555        Home     Alone   Sunny           80   6PM
# 1048556        Home   Partner   Sunny           30  10PM
# 1048573        Home     Alone   Sunny           30   6PM
# 1048574        Home     Alone   Rainy           55  10PM
#
#                         coupon expiration  gender     age      maritalStatus  \
# 13                         Bar         1d  Female      21  Unmarried partner
# 14           Restaurant(20-50)         1d  Female      21  Unmarried partner
# 15                Coffee House         2h  Female      21  Unmarried partner
# 35                         Bar         1d    Male      21             Single
# 36           Restaurant(20-50)         1d    Male      21             Single
# ...                        ...        ...     ...     ...                ...
# 1048554      Restaurant(20-50)         2h  Female  50plus    Married partner
# 1048555                    Bar         2h  Female  50plus    Married partner
# 1048556  Carry out & Take away         2h  Female  50plus    Married partner
# 1048573  Carry out & Take away         2h  Female  50plus             Single
# 1048574           Coffee House         1d  Female  50plus             Single
#
#          ...  Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min  \
# 13       ...               1~3                1                 0
# 14       ...               1~3                1                 1
# 15       ...               1~3                1                 0
# 35       ...             less1                1                 0
# 36       ...             less1                1                 1
# ...      ...               ...              ...               ...
# 1048554  ...             less1                1                 0
# 1048555  ...             less1                1                 0
# 1048556  ...             less1                1                 1
# 1048573  ...               1~3                1                 1
# 1048574  ...               1~3                1                 0
#
#         toCoupon_GEQ25min direction_same direction_opp  Y row_count df1 df2
# 13                      0              1             0  1        14 NaN NaN
# 14                      0              0             1  1        15 NaN NaN
# 15                      0              0             1  0        16 NaN NaN
# 35                      0              1             0  1        36 NaN NaN
# 36                      0              0             1  0        37 NaN NaN
# ...                   ...            ...           ... ..       ...  ..  ..
# 1048554                 0              0             1  0      8467 NaN NaN
# 1048555                 0              1             0  0      8468 NaN NaN
# 1048556                 0              0             1  1      8469 NaN NaN
# 1048573                 0              1             0  1      8486 NaN NaN
# 1048574                 0              1             0  0      8487 NaN NaN
#
# [267302 rows x 29 columns]

# %%
df.sort_values('coupon')
# Out:
#             destination  passanger weather  temperature  time  \
# 528118             Home      Alone   Sunny           80   6PM
# 681388             Work      Alone   Rainy           55   7AM
# 156586  No Urgent Place    Partner   Sunny           80   6PM
# 894042             Home      Alone   Sunny           80  10PM
# 372658             Home      Alone   Sunny           80  10PM
# ...                 ...        ...     ...          ...   ...
# 182793  No Urgent Place  Friend(s)   Sunny           80   2PM
# 676195  No Urgent Place     Kid(s)   Sunny           55   2PM
# 676194  No Urgent Place     Kid(s)   Sunny           80   2PM
# 377989             Home      Alone   Snowy           30  10PM
# 0       No Urgent Place      Alone   Sunny           55   2PM
#
#                  coupon expiration  gender age      maritalStatus  ...  \
# 528118              Bar         2h    Male  21             Single  ...
# 681388              Bar         1d  Female  21    Married partner  ...
# 156586              Bar         2h    Male  21  Unmarried partner  ...
# 894042              Bar         1d    Male  46    Married partner  ...
# 372658              Bar         1d  Female  31             Single  ...
# ...                 ...        ...     ...  ..                ...  ...
# 182793  Restaurant(<20)         2h    Male  31    Married partner  ...
# 676195  Restaurant(<20)         1d    Male  26    Married partner  ...
# 676194  Restaurant(<20)         1d    Male  26    Married partner  ...
# 377989  Restaurant(<20)         2h    Male  31    Married partner  ...
# 0       Restaurant(<20)         1d  Female  21  Unmarried partner  ...
#
#         Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min  \
# 528118               1~3                1                 0                 0
# 681388               1~3                1                 1                 1
# 156586             never                1                 1                 0
# 894042               1~3                1                 1                 0
# 372658             less1                1                 1                 0
# ...                  ...              ...               ...               ...
# 182793             less1                1                 1                 0
# 676195               1~3                1                 1                 0
# 676194               1~3                1                 0                 0
# 377989               1~3                1                 1                 1
# 0                    1~3                1                 0                 0
#
#        direction_same direction_opp  Y row_count df1 df2
# 528118              1             0  1      8075 NaN NaN
# 681388              0             1  1      9137 NaN NaN
# 156586              0             1  0      4379 NaN NaN
# 894042              1             0  0      6163 NaN NaN
# 372658              1             0  1      4823 NaN NaN
# ...               ...           ... ..       ...  ..  ..
# 182793              0             1  0      5218 NaN NaN
# 676195              0             1  1      3944 NaN NaN
# 676194              0             1  1      3943 NaN NaN
# 377989              0             1  1     10154 NaN NaN
# 0                   0             1  1         1 NaN NaN
#
# [1048575 rows x 29 columns]

# %%
df.rename(columns={'destination':'Destination'},inplace=True)

# %%
df
# Out:
#              Destination  passanger weather  temperature  time  \
# 0        No Urgent Place      Alone   Sunny           55   2PM
# 1        No Urgent Place  Friend(s)   Sunny           80  10AM
# 2        No Urgent Place  Friend(s)   Sunny           80  10AM
# 3        No Urgent Place  Friend(s)   Sunny           80   2PM
# 4        No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                  ...        ...     ...          ...   ...
# 1048570  No Urgent Place  Friend(s)   Snowy           30  10AM
# 1048571  No Urgent Place  Friend(s)   Snowy           30  10PM
# 1048572  No Urgent Place      Alone   Sunny           80  10AM
# 1048573             Home      Alone   Sunny           30   6PM
# 1048574             Home      Alone   Rainy           55  10PM
#
#                         coupon expiration  gender     age      maritalStatus  \
# 0              Restaurant(<20)         1d  Female      21  Unmarried partner
# 1                 Coffee House         2h  Female      21  Unmarried partner
# 2        Carry out & Take away         2h  Female      21  Unmarried partner
# 3                 Coffee House         2h  Female      21  Unmarried partner
# 4                 Coffee House         1d  Female      21  Unmarried partner
# ...                        ...        ...     ...     ...                ...
# 1048570  Carry out & Take away         1d  Female  50plus             Single
# 1048571  Carry out & Take away         1d  Female  50plus             Single
# 1048572           Coffee House         1d  Female  50plus             Single
# 1048573  Carry out & Take away         2h  Female  50plus             Single
# 1048574           Coffee House         1d  Female  50plus             Single
#
#          ...  Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min  \
# 0        ...               1~3                1                 0
# 1        ...               1~3                1                 0
# 2        ...               1~3                1                 1
# 3        ...               1~3                1                 1
# 4        ...               1~3                1                 1
# ...      ...               ...              ...               ...
# 1048570  ...               1~3                1                 1
# 1048571  ...               1~3                1                 1
# 1048572  ...               1~3                1                 0
# 1048573  ...               1~3                1                 1
# 1048574  ...               1~3                1                 0
#
#         toCoupon_GEQ25min direction_same direction_opp  Y row_count df1 df2
# 0                       0              0             1  1         1 NaN NaN
# 1                       0              0             1  0         2 NaN NaN
# 2                       0              0             1  1         3 NaN NaN
# 3                       0              0             1  0         4 NaN NaN
# 4                       0              0             1  0         5 NaN NaN
# ...                   ...            ...           ... ..       ...  ..  ..
# 1048570                 0              0             1  0      8483 NaN NaN
# 1048571                 0              0             1  0      8484 NaN NaN
# 1048572                 0              0             1  1      8485 NaN NaN
# 1048573                 0              1             0  1      8486 NaN NaN
# 1048574                 0              1             0  0      8487 NaN NaN
#
# [1048575 rows x 29 columns]

# %%
df.groupby('occupation').size().to_frame('Count').reset_index()
# Out:
#                                    occupation   Count
# 0                  Architecture & Engineering   14503
# 1    Arts Design Entertainment Sports & Media   52020
# 2   Building & Grounds Cleaning & Maintenance    3652
# 3                        Business & Financial   44912
# 4                 Community & Social Services   19894
# 5                     Computer & Mathematical  116403
# 6                   Construction & Extraction   12760
# 7                  Education&Training&Library   78051
# 8                  Farming Fishing & Forestry    3547
# 9          Food Preparation & Serving Related   24568
# 10       Healthcare Practitioners & Technical   20186
# 11                         Healthcare Support   19954
# 12          Installation Maintenance & Repair   11017
# 13                                      Legal   18089
# 14               Life Physical Social Science   14110
# 15                                 Management   69438
# 16            Office & Administrative Support   52728
# 17                    Personal Care & Service   14481
# 18                     Production Occupations    9064
# 19                         Protective Service   14481
# 20                                    Retired   40976
# 21                            Sales & Related   90388
# 22                                    Student  130808
# 23           Transportation & Material Moving   18050
# 24                                 Unemployed  154495

# %%
df.groupby('weather')['temperature'].mean().to_frame('avg_temp').reset_index()
# Out:
#   weather   avg_temp
# 0   Rainy  55.000000
# 1   Snowy  30.000000
# 2   Sunny  68.962811

# %%
df.groupby('weather')['temperature'].size().to_frame('Count_temp').reset_index()
# Out:
#   weather  Count_temp
# 0   Rainy       99565
# 1   Snowy      115734
# 2   Sunny      833276

# %%
df.groupby('weather')['temperature'].nunique().to_frame('count_distinct_temp').reset_index()
# Out:
#   weather  count_distinct_temp
# 0   Rainy                    1
# 1   Snowy                    1
# 2   Sunny                    3

# %%
df.groupby('weather')['temperature'].sum().to_frame('sum_temp').reset_index()
# Out:
#   weather  sum_temp
# 0   Rainy   5476075
# 1   Snowy   3472020
# 2   Sunny  57465055

# %%
df.groupby('weather')['temperature'].min().to_frame('min_temp').reset_index()
# Out:
#   weather  min_temp
# 0   Rainy        55
# 1   Snowy        30
# 2   Sunny        30

# %%
df.groupby('weather')['temperature'].max().to_frame('max_temp').reset_index()
# Out:
#   weather  max_temp
# 0   Rainy        55
# 1   Snowy        30
# 2   Sunny        80

# %%
df.groupby('occupation').filter(lambda x: x['occupation'].iloc[0] =='Student').groupby('occupation').size()
# Out:
# occupation
# Student    130808
# dtype: int64

# %%
df1=df
df1
# Out:
#              Destination  passanger weather  temperature  time  \
# 0        No Urgent Place      Alone   Sunny           55   2PM
# 1        No Urgent Place  Friend(s)   Sunny           80  10AM
# 2        No Urgent Place  Friend(s)   Sunny           80  10AM
# 3        No Urgent Place  Friend(s)   Sunny           80   2PM
# 4        No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                  ...        ...     ...          ...   ...
# 1048570  No Urgent Place  Friend(s)   Snowy           30  10AM
# 1048571  No Urgent Place  Friend(s)   Snowy           30  10PM
# 1048572  No Urgent Place      Alone   Sunny           80  10AM
# 1048573             Home      Alone   Sunny           30   6PM
# 1048574             Home      Alone   Rainy           55  10PM
#
#                         coupon expiration  gender     age      maritalStatus  \
# 0              Restaurant(<20)         1d  Female      21  Unmarried partner
# 1                 Coffee House         2h  Female      21  Unmarried partner
# 2        Carry out & Take away         2h  Female      21  Unmarried partner
# 3                 Coffee House         2h  Female      21  Unmarried partner
# 4                 Coffee House         1d  Female      21  Unmarried partner
# ...                        ...        ...     ...     ...                ...
# 1048570  Carry out & Take away         1d  Female  50plus             Single
# 1048571  Carry out & Take away         1d  Female  50plus             Single
# 1048572           Coffee House         1d  Female  50plus             Single
# 1048573  Carry out & Take away         2h  Female  50plus             Single
# 1048574           Coffee House         1d  Female  50plus             Single
#
#          ...  Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min  \
# 0        ...               1~3                1                 0
# 1        ...               1~3                1                 0
# 2        ...               1~3                1                 1
# 3        ...               1~3                1                 1
# 4        ...               1~3                1                 1
# ...      ...               ...              ...               ...
# 1048570  ...               1~3                1                 1
# 1048571  ...               1~3                1                 1
# 1048572  ...               1~3                1                 0
# 1048573  ...               1~3                1                 1
# 1048574  ...               1~3                1                 0
#
#         toCoupon_GEQ25min direction_same direction_opp  Y row_count df1 df2
# 0                       0              0             1  1         1 NaN NaN
# 1                       0              0             1  0         2 NaN NaN
# 2                       0              0             1  1         3 NaN NaN
# 3                       0              0             1  0         4 NaN NaN
# 4                       0              0             1  0         5 NaN NaN
# ...                   ...            ...           ... ..       ...  ..  ..
# 1048570                 0              0             1  0      8483 NaN NaN
# 1048571                 0              0             1  0      8484 NaN NaN
# 1048572                 0              0             1  1      8485 NaN NaN
# 1048573                 0              1             0  1      8486 NaN NaN
# 1048574                 0              1             0  0      8487 NaN NaN
#
# [1048575 rows x 29 columns]

# %%
pd.concat([df, df1])['Destination'].drop_duplicates()
# Out:
# 0     No Urgent Place
# 13               Home
# 16               Work
# Name: Destination, dtype: object

# %%
df1
# Out:
#              Destination  passanger weather  temperature  time  \
# 0        No Urgent Place      Alone   Sunny           55   2PM
# 1        No Urgent Place  Friend(s)   Sunny           80  10AM
# 2        No Urgent Place  Friend(s)   Sunny           80  10AM
# 3        No Urgent Place  Friend(s)   Sunny           80   2PM
# 4        No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                  ...        ...     ...          ...   ...
# 1048570  No Urgent Place  Friend(s)   Snowy           30  10AM
# 1048571  No Urgent Place  Friend(s)   Snowy           30  10PM
# 1048572  No Urgent Place      Alone   Sunny           80  10AM
# 1048573             Home      Alone   Sunny           30   6PM
# 1048574             Home      Alone   Rainy           55  10PM
#
#                         coupon expiration  gender     age      maritalStatus  \
# 0              Restaurant(<20)         1d  Female      21  Unmarried partner
# 1                 Coffee House         2h  Female      21  Unmarried partner
# 2        Carry out & Take away         2h  Female      21  Unmarried partner
# 3                 Coffee House         2h  Female      21  Unmarried partner
# 4                 Coffee House         1d  Female      21  Unmarried partner
# ...                        ...        ...     ...     ...                ...
# 1048570  Carry out & Take away         1d  Female  50plus             Single
# 1048571  Carry out & Take away         1d  Female  50plus             Single
# 1048572           Coffee House         1d  Female  50plus             Single
# 1048573  Carry out & Take away         2h  Female  50plus             Single
# 1048574           Coffee House         1d  Female  50plus             Single
#
#          ...  Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min  \
# 0        ...               1~3                1                 0
# 1        ...               1~3                1                 0
# 2        ...               1~3                1                 1
# 3        ...               1~3                1                 1
# 4        ...               1~3                1                 1
# ...      ...               ...              ...               ...
# 1048570  ...               1~3                1                 1
# 1048571  ...               1~3                1                 1
# 1048572  ...               1~3                1                 0
# 1048573  ...               1~3                1                 1
# 1048574  ...               1~3                1                 0
#
#         toCoupon_GEQ25min direction_same direction_opp  Y row_count df1 df2
# 0                       0              0             1  1         1 NaN NaN
# 1                       0              0             1  0         2 NaN NaN
# 2                       0              0             1  1         3 NaN NaN
# 3                       0              0             1  0         4 NaN NaN
# 4                       0              0             1  0         5 NaN NaN
# ...                   ...            ...           ... ..       ...  ..  ..
# 1048570                 0              0             1  0      8483 NaN NaN
# 1048571                 0              0             1  0      8484 NaN NaN
# 1048572                 0              0             1  1      8485 NaN NaN
# 1048573                 0              1             0  1      8486 NaN NaN
# 1048574                 0              1             0  0      8487 NaN NaN
#
# [1048575 rows x 29 columns]

# %%
df[df['passanger'] == 'Alone'][['Destination', 'passanger']]
# Out:
#              Destination passanger
# 0        No Urgent Place     Alone
# 13                  Home     Alone
# 14                  Home     Alone
# 15                  Home     Alone
# 16                  Work     Alone
# ...                  ...       ...
# 1048561  No Urgent Place     Alone
# 1048563  No Urgent Place     Alone
# 1048572  No Urgent Place     Alone
# 1048573             Home     Alone
# 1048574             Home     Alone
#
# [603606 rows x 2 columns]

# %%
df[df['weather'].str.startswith('Sun')]
# Out:
#              Destination  passanger weather  temperature  time  \
# 0        No Urgent Place      Alone   Sunny           55   2PM
# 1        No Urgent Place  Friend(s)   Sunny           80  10AM
# 2        No Urgent Place  Friend(s)   Sunny           80  10AM
# 3        No Urgent Place  Friend(s)   Sunny           80   2PM
# 4        No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                  ...        ...     ...          ...   ...
# 1048566  No Urgent Place  Friend(s)   Sunny           55  10AM
# 1048567  No Urgent Place  Friend(s)   Sunny           55   6PM
# 1048568  No Urgent Place  Friend(s)   Sunny           30  10PM
# 1048572  No Urgent Place      Alone   Sunny           80  10AM
# 1048573             Home      Alone   Sunny           30   6PM
#
#                         coupon expiration  gender     age      maritalStatus  \
# 0              Restaurant(<20)         1d  Female      21  Unmarried partner
# 1                 Coffee House         2h  Female      21  Unmarried partner
# 2        Carry out & Take away         2h  Female      21  Unmarried partner
# 3                 Coffee House         2h  Female      21  Unmarried partner
# 4                 Coffee House         1d  Female      21  Unmarried partner
# ...                        ...        ...     ...     ...                ...
# 1048566           Coffee House         1d  Female  50plus             Single
# 1048567  Carry out & Take away         1d  Female  50plus             Single
# 1048568        Restaurant(<20)         2h  Female  50plus             Single
# 1048572           Coffee House         1d  Female  50plus             Single
# 1048573  Carry out & Take away         2h  Female  50plus             Single
#
#          ...  Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min  \
# 0        ...               1~3                1                 0
# 1        ...               1~3                1                 0
# 2        ...               1~3                1                 1
# 3        ...               1~3                1                 1
# 4        ...               1~3                1                 1
# ...      ...               ...              ...               ...
# 1048566  ...               1~3                1                 1
# 1048567  ...               1~3                1                 1
# 1048568  ...               1~3                1                 0
# 1048572  ...               1~3                1                 0
# 1048573  ...               1~3                1                 1
#
#         toCoupon_GEQ25min direction_same direction_opp  Y row_count df1 df2
# 0                       0              0             1  1         1 NaN NaN
# 1                       0              0             1  0         2 NaN NaN
# 2                       0              0             1  1         3 NaN NaN
# 3                       0              0             1  0         4 NaN NaN
# 4                       0              0             1  0         5 NaN NaN
# ...                   ...            ...           ... ..       ...  ..  ..
# 1048566                 0              0             1  1      8479 NaN NaN
# 1048567                 0              0             1  0      8480 NaN NaN
# 1048568                 0              0             1  0      8481 NaN NaN
# 1048572                 0              0             1  1      8485 NaN NaN
# 1048573                 0              1             0  1      8486 NaN NaN
#
# [833276 rows x 29 columns]

# %%
df[(df['temperature'] >= 29) & (df['temperature'] <= 75)]['temperature'].unique()
# Out:
# array([55, 30], dtype=int64)

# %%
df[df['occupation'].isin(['Sales & Related', 'Management'])][['occupation']]
# Out:
#               occupation
# 193      Sales & Related
# 194      Sales & Related
# 195      Sales & Related
# 196      Sales & Related
# 197      Sales & Related
# ...                  ...
# 1048447  Sales & Related
# 1048448  Sales & Related
# 1048449  Sales & Related
# 1048450  Sales & Related
# 1048451  Sales & Related
#
# [159826 rows x 1 columns]
